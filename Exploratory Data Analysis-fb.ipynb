# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\dataset_Facebook.csv",delimiter=';')

# %%
df.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df1=df.drop(df.columns[7:15],axis=1)

# %%
df1.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  comment    like  share  Total Interactions
# 0   0.0        4    79.0   17.0                 100
# 1   0.0        5   130.0   29.0                 164
# 2   0.0        0    66.0   14.0                  80
# 3   1.0       58  1572.0  147.0                1777
# 4   0.0       19   325.0   49.0                 393

# %%
df1.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid    comment         like       share  Total Interactions
# count  499.000000  500.00000   499.000000  496.000000          500.000000
# mean     0.278557    7.48200   177.945892   27.266129          212.120000
# std      0.448739   21.18091   323.398742   42.613292          380.233118
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
# Page total likes      500 non-null int64
# Type                  500 non-null object
# Category              500 non-null int64
# Post Month            500 non-null int64
# Post Weekday          500 non-null int64
# Post Hour             500 non-null int64
# Paid                  499 non-null float64
# comment               500 non-null int64
# like                  499 non-null float64
# share                 496 non-null float64
# Total Interactions    500 non-null int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 43.0+ KB

# %%
df1['Type'].value_counts()
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
df1['Paid'].value_counts()
# Out:
# 0.0    360
# 1.0    139
# Name: Paid, dtype: int64

# %%
df['like'].fillna(0,inplace=True)
df['share'].fillna(0,inplace=True)
df['Paid'].fillna(0,inplace=True)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  500.000000                  500.00000                     5.000000e+02
# mean     0.278000                13903.36000                     2.958595e+04
# ...

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Category',y='Lifetime Engaged Users',hue='Paid',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Category")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Category',y='Lifetime Engaged Users',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Category")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Type',y='Lifetime Engaged Users',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Type")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Type',y='Lifetime Engaged Users',hue='Category',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Category vs Type")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Paid',y='Lifetime Engaged Users',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Paid")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Type',y='Lifetime Engaged Users',hue='Paid',data=df,palette='viridis',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Category vs Paid ")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Post Month',y='Lifetime Engaged Users',data=df,palette='vlag',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Month")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Post Weekday',y='Lifetime Engaged Users',data=df,palette='rocket',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Week Day")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Post Hour',y='Lifetime Engaged Users',data=df,palette='rocket',ci=None)
plt.ylabel("Lifetime Engaged Users")
plt.title("Lifetime Engaged Users vs. Post Hour")
plt.savefig('catCount.png', bbox_inches='tight')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True,cbar=True)

# %%
sns.distplot(df['Lifetime Engaged Users'],bins=100)
plt.xlim(-1000,4000)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (-1000, 4000)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['Lifetime Engaged Users'])
#plt.xlim(0,3000)

# %%
df.shape
# Out:
# (500, 19)
